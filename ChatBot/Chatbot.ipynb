# %% [markdown]
# https://data-flair.training/blogs/python-chatbot-project/
# 1. Import and load the data file
#
# First, make a file name as train_chatbot.py. We import the necessary packages for our chatbot and initialize the variables we will use in our Python project.
#
# The data file is in JSON format so we used the json package to parse the JSON file into Python.

# %%
import json

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open(r'C:\Users\mshch96\Desktop\Capstone\Github\ChatBot\intents.json').read()
intents = json.loads(data_file)

# %%
intents
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi there',
#     'How are you',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day'],
#    'responses': ['Hello, thanks for asking',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'context': ['']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'options',
#    'patterns': ['How you could help me?',
#     'What you can do?',
#     'What help you provide?',
#     'How you can be helpful?',
#     'What support is offered'],
#    'responses': ['I can offer Dell Quick Answer, or guide you to the Dell Helpdesk',
#     'I can provide frequently asked questions-answers'],
#    'context': ['']},
#   {'tag': 'password',
#    'patterns': ['What if i forget password?',
#     'admin password',
#     'reset password',
#     'find password back'],
#    'responses': ['Try remember it, if you cannot, we cannot help you neither : ('],
#    'context': ['']},
#   {'tag': 'internet_issue',
#    'patterns': ['No connection to the server',
#     'cannot open web browser',
#     'cannot open youtube',
#     'no access to dell emails'],
#    'responses': ['make sure you connected Dell VPN before try access anything internal'],
#    'context': ['']},
#   {'tag': 'software_crush',
#    'patterns': ['Microsoft team crushed',
#     'Dell HR froze',
#     'click without responses'],
#    'responses': ['try restart computer, try restart the program, try restart VM'],
#    'context': ['']},
#   {'tag': 'dell_helpdesk',
#    'patterns': ['Find me a representitive',
#     'I need a real person',
#     'helpdesk',
#     'phone number'],
#    'responses': ['Please provide your name'],
#    'context': ['search_representative']},
#   {'tag': 'search_representative',
#    'patterns': [],
#    'responses': ['Please wait for an representative or contact ----'],
#    'context': ['']}]}

# %% [markdown]
# 2. Preprocess data
#
# When working with text data, we need to perform various preprocessing on the data before we make a machine learning or a deep learning model. Tokenizing is the most basic and first thing you can do on text data. Tokenizing is the process of breaking the whole text into small parts like words.
#
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word 
        # ['Hi', 'there'] ['Is', 'anyone', 'there', '?']
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# Now we will lemmatize each word and remove duplicate words from the list. Lemmatizing is the process of converting a word into its lemma form and then creating a pickle file to store the Python objects which we will use while predicting.

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
# Out:
# 37 documents
# 8 classes ['dell_helpdesk', 'goodbye', 'greeting', 'internet_issue', 'options', 'password', 'software_crush', 'thanks']
# 77 unique lemmatized words ["'s", ',', 'a', 'access', 'admin', 'anyone', 'are', 'awesome', 'back', 'be', 'browser', 'bye', 'can', 'chatting', 'click', 'connection', 'could', 'crushed', 'day', 'dell', 'do', 'email', 'find', 'for', 'forget', 'froze', 'good', 'goodbye', 'hello', 'help', 'helpdesk', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'hr', 'i', 'if', 'is', 'later', 'me', 'microsoft', 'need', 'next', 'nice', 'no', 'not', 'number', 'offered', 'open', 'password', 'person', 'phone', 'provide', 'real', 'representitive', 'reset', 'response', 'see', 'server', 'support', 'team', 'thank', 'thanks', 'that', 'the', 'there', 'till', 'time', 'to', 'web', 'what', 'without', 'you', 'youtube']

# %%
import pickle

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %% [markdown]
# 3. Create training and testing data
#
# Now, we will create the training data in which we will provide the input and the output. Our input will be the pattern and output will be the class our input pattern belongs to. But the computer doesn’t understand text so we will convert text into numbers.

# %%
import random
import numpy as np

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\mshch96\Anaconda2\envs\p36workshop\lib\site-packages\ipykernel_launcher.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# 4. Build the model
#
# We have our training data ready, now we will build a deep neural network that has 3 layers. We use the Keras sequential API for this. After training the model for 200 epochs, we achieved 100% accuracy on our model. Let us save the model as ‘chatbot_model.h5’.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save(r'C:\Users\mshch96\Desktop\Capstone\Github\ChatBot\chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 1ms/step - loss: 2.0419 - accuracy: 0.2420
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0198 - accuracy: 0.1508
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9791 - accuracy: 0.1951
# Epoch 4/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.9965 - accuracy: 0.3391
# Epoch 5/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.9472 - accuracy: 0.1651
# Epoch 6/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8861 - accuracy: 0.3519
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8406 - accuracy: 0.2402
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7457 - accuracy: 0.4233
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7159 - accuracy: 0.4320
# Epoch 10/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.5375 - accuracy: 0.6418
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5978 - accuracy: 0.5004
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4506 - accuracy: 0.6032
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3322 - accuracy: 0.5949
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1524 - accuracy: 0.5944
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1470 - accuracy: 0.7513
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8892 - accuracy: 0.8017
# Epoch 17/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.1870 - accuracy: 0.6290
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9166 - accuracy: 0.7612
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9146 - accuracy: 0.7720
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6989 - accuracy: 0.8512
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6991 - accuracy: 0.8531
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.9203
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.9235
# Epoch 24/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6485 - accuracy: 0.7197
# Epoch 25/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4480 - accuracy: 0.9827
# Epoch 26/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5849 - accuracy: 0.8483
# Epoch 27/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3529 - accuracy: 0.9697
# Epoch 28/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2523 - accuracy: 0.9568
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3961 - accuracy: 0.9222
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3047 - accuracy: 0.9779
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.9272
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8727
# Epoch 33/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.9771
# Epoch 34/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3162 - accuracy: 0.9221
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9827
# Epoch 36/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2483 - accuracy: 0.9235
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.9351
# Epoch 38/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1418 - accuracy: 1.0000
# Epoch 39/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3566 - accuracy: 0.8599
# Epoch 40/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1764 - accuracy: 1.0000
# Epoch 41/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3023 - accuracy: 0.9272
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3020 - accuracy: 0.9697
# Epoch 43/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2663 - accuracy: 0.9688
# Epoch 44/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1376 - accuracy: 0.9586
# Epoch 45/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9771
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1291 - accuracy: 0.9283
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1218 - accuracy: 0.9697
# Epoch 48/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9586
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 1.0000
# Epoch 50/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0576 - accuracy: 0.9771
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1277 - accuracy: 0.9586
# Epoch 52/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 1.0000
# Epoch 53/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1827 - accuracy: 0.9235
# Epoch 54/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0638 - accuracy: 1.0000
# Epoch 55/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 1.0000
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1383 - accuracy: 0.9871
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0952 - accuracy: 0.9697
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0847 - accuracy: 0.9586
# Epoch 59/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1791 - accuracy: 1.0000
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9940
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 0.9779
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0620 - accuracy: 1.0000
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1192 - accuracy: 0.9771
# Epoch 66/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 1.0000
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9871
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 1.0000
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 1.0000
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 72/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0950 - accuracy: 0.9586
# Epoch 73/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.9190
# Epoch 74/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0488 - accuracy: 1.0000
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1392 - accuracy: 0.9457
# Epoch 76/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 78/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 79/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 80/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 81/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1056 - accuracy: 1.0000
# Epoch 82/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 83/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 84/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1616 - accuracy: 0.9586
# Epoch 85/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0495 - accuracy: 0.9827
# Epoch 86/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0982 - accuracy: 0.9698
# Epoch 87/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 88/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 89/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0620 - accuracy: 0.9586
# Epoch 90/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 1.0000
# Epoch 91/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 1.0000
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9940
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.9586
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 99/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1038 - accuracy: 0.9908
# Epoch 100/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1935 - accuracy: 0.8647
# Epoch 101/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 102/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 106/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 107/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0656 - accuracy: 0.9697
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1395 - accuracy: 0.9779
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.9542
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 115/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 116/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 117/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1131 - accuracy: 0.9135
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 1.0000
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0904 - accuracy: 0.9283
# Epoch 121/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9940
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9871
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9697
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 132/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 133/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 1.0000
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 142/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 143/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0588 - accuracy: 0.9697
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 145/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 146/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9771
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9827
# Epoch 158/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 159/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0630 - accuracy: 1.0000
# Epoch 160/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 161/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 162/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9908
# Epoch 163/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 166/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 167/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 0.9827
# Epoch 168/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0821 - accuracy: 0.9908
# Epoch 169/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 170/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 0.9771
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9586
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 179/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 180/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 183/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 0.9771
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9586
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9871
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.9586
# Epoch 189/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 190/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 192/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 195/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 197/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9827
# Epoch 198/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 199/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0492 - accuracy: 0.9827
# Epoch 200/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0368 - accuracy: 1.0000
# model created
